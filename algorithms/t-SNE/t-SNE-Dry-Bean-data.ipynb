# %% [markdown]
# # t-distributed Stochastic Network Embedding (t-SNE)
# ### Dataset: [Dry_Bean_Dataset.xlsx](../../input/Dry_Bean_Dataset_Citation_Request.txt)

# %% [markdown]
# <a id="1"></a>
# ## Import modules

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <a id="2"></a>
# ## Loading dataset

# %%
filename = '../../input/Dry_Bean_Dataset.xlsx'
df = pd.read_excel(filename)  

print(df)
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653248  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13606  DERMASON
# 13607  DERMASON
# 13608  DERMASON
# 13609  DERMASON
# 13610  DERMASON
#
# [13611 rows x 17 columns]

# %% [markdown]
# <a id="3"></a>
# ## Standardize the data

# %%
features = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength', 'AspectRation', 'Eccentricity']
target = 'Class'

X = df[features].values
y = df[target].values

x = StandardScaler().fit_transform(X)

# %% [markdown]
# <a id="4"></a>
# ## t-SNE Projection to 2D

# %%
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# define perplexity values to explore
perplexity_values = [5, 30, 50]

# loop over each perplexity value
for perplexity in perplexity_values:
    # initialize and fit t-SNE
    tsne = TSNE(n_components=2, verbose=1, perplexity=perplexity)
    tsne_result = tsne.fit_transform(x)
    
    # create a DataFrame for visualization
    tsne_result_df = pd.DataFrame({'tsne_1': tsne_result[:,0], 'tsne_2': tsne_result[:,1], 'class': y})
    
    # plotting
    plt.figure(figsize=(16, 10))
    sns.scatterplot(
        x='tsne_1', y='tsne_2',
        hue='class',
        data=tsne_result_df,
        palette=sns.color_palette("hsv", len(df[target].unique())),
        legend="full",
        alpha=0.3
    )
    plt.title(f't-SNE visualization with perplexity={perplexity}')
    plt.show()
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 13611 samples in 0.005s...
# [t-SNE] Computed neighbors for 13611 samples in 0.077s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13611
# [t-SNE] Computed conditional probabilities for sample 2000 / 13611
# [t-SNE] Computed conditional probabilities for sample 3000 / 13611
# [t-SNE] Computed conditional probabilities for sample 4000 / 13611
# [t-SNE] Computed conditional probabilities for sample 5000 / 13611
# [t-SNE] Computed conditional probabilities for sample 6000 / 13611
# [t-SNE] Computed conditional probabilities for sample 7000 / 13611
# [t-SNE] Computed conditional probabilities for sample 8000 / 13611
# [t-SNE] Computed conditional probabilities for sample 9000 / 13611
# [t-SNE] Computed conditional probabilities for sample 10000 / 13611
# [t-SNE] Computed conditional probabilities for sample 11000 / 13611
# [t-SNE] Computed conditional probabilities for sample 12000 / 13611
# [t-SNE] Computed conditional probabilities for sample 13000 / 13611
# [t-SNE] Computed conditional probabilities for sample 13611 / 13611
# [t-SNE] Mean sigma: 0.028502
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 86.421379
# [t-SNE] KL divergence after 1000 iterations: 1.304360
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 13611 samples in 0.004s...
# [t-SNE] Computed neighbors for 13611 samples in 0.264s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13611
# [t-SNE] Computed conditional probabilities for sample 2000 / 13611
# [t-SNE] Computed conditional probabilities for sample 3000 / 13611
# [t-SNE] Computed conditional probabilities for sample 4000 / 13611
# [t-SNE] Computed conditional probabilities for sample 5000 / 13611
# [t-SNE] Computed conditional probabilities for sample 6000 / 13611
# [t-SNE] Computed conditional probabilities for sample 7000 / 13611
# [t-SNE] Computed conditional probabilities for sample 8000 / 13611
# [t-SNE] Computed conditional probabilities for sample 9000 / 13611
# [t-SNE] Computed conditional probabilities for sample 10000 / 13611
# [t-SNE] Computed conditional probabilities for sample 11000 / 13611
# [t-SNE] Computed conditional probabilities for sample 12000 / 13611
# [t-SNE] Computed conditional probabilities for sample 13000 / 13611
# [t-SNE] Computed conditional probabilities for sample 13611 / 13611
# [t-SNE] Mean sigma: 0.066541
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.625671
# [t-SNE] KL divergence after 1000 iterations: 0.858700
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 13611 samples in 0.004s...
# [t-SNE] Computed neighbors for 13611 samples in 0.529s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13611
# [t-SNE] Computed conditional probabilities for sample 2000 / 13611
# [t-SNE] Computed conditional probabilities for sample 3000 / 13611
# [t-SNE] Computed conditional probabilities for sample 4000 / 13611
# [t-SNE] Computed conditional probabilities for sample 5000 / 13611
# [t-SNE] Computed conditional probabilities for sample 6000 / 13611
# [t-SNE] Computed conditional probabilities for sample 7000 / 13611
# [t-SNE] Computed conditional probabilities for sample 8000 / 13611
# [t-SNE] Computed conditional probabilities for sample 9000 / 13611
# [t-SNE] Computed conditional probabilities for sample 10000 / 13611
# [t-SNE] Computed conditional probabilities for sample 11000 / 13611
# [t-SNE] Computed conditional probabilities for sample 12000 / 13611
# [t-SNE] Computed conditional probabilities for sample 13000 / 13611
# [t-SNE] Computed conditional probabilities for sample 13611 / 13611
# [t-SNE] Mean sigma: 0.084687
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.348618
# [t-SNE] KL divergence after 1000 iterations: 0.782345

# %% [markdown]
# <a id="5"></a>
# ## Visualize 2D Projection

# %%
tsne_result_df = pd.DataFrame({'tsne_1': tsne_result[:,0], 'tsne_2': tsne_result[:,1], 'class': y})
fig, ax = plt.subplots(1)
sns.scatterplot(x='tsne_1', y='tsne_2', hue='class', data=tsne_result_df, ax=ax,s=10, palette=sns.color_palette(n_colors=6))
lim = (tsne_result.min()-5, tsne_result.max()+5)
ax.set_xlim(lim)
ax.set_ylim(lim)
ax.set_aspect('equal')
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)
plt.show()
# Out:
# /var/folders/v4/0f9n6lpx3pn7ghtrplsk92h80000gn/T/ipykernel_69790/3185144506.py:3: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(x='tsne_1', y='tsne_2', hue='class', data=tsne_result_df, ax=ax,s=10, palette=sns.color_palette(n_colors=6))
